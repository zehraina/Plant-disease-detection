# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf
from tensorflow import keras
# Out:
# 2023-10-25 18:45:23.824546: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pathlib
data_dir='../Dataset/PlantVillage_potato'
test_dir='../Dataset/potato_test/'
data_dir=pathlib.Path(data_dir)
test_dir=pathlib.Path(test_dir)
data_dir
# Out:
# PosixPath('../Dataset/PlantVillage_potato')

# %%
os.listdir(data_dir)
# Out:
# ['Potato___Late_blight', 'Potato___Early_blight', 'Potato___healthy']

# %%
image_count=len(list(data_dir.glob('*/*.JPG')))
image_count
# Out:
# 2152

# %%
early_blight=list(data_dir.glob('Potato___Early_blight/*'))
early_blight[:5]
# Out:
# [PosixPath('../Dataset/PlantVillage_potato/Potato___Early_blight/fd59ab68-681f-4aca-ae95-6f73bf8caad7___RS_Early.B 7118.JPG'),
#  PosixPath('../Dataset/PlantVillage_potato/Potato___Early_blight/be89d35f-e382-4b1c-95e8-af88d969d306___RS_Early.B 6758.JPG'),
#  PosixPath('../Dataset/PlantVillage_potato/Potato___Early_blight/c17c36ed-c36f-42d4-812d-3b17158063d3___RS_Early.B 8398.JPG'),
#  PosixPath('../Dataset/PlantVillage_potato/Potato___Early_blight/26f15c9c-5cbf-49c8-ac4e-c5b15d03e319___RS_Early.B 9022.JPG'),
#  PosixPath('../Dataset/PlantVillage_potato/Potato___Early_blight/10a3920b-dd04-406d-8bbd-f92f221e4dee___RS_Early.B 7035.JPG')]

# %%
k=PIL.Image.open(str(early_blight[2]))

# %%
potato_disease_dict={
    'early_blight':list(data_dir.glob('Potato___Early_blight/*')),
    'late_blight':list(data_dir.glob('Potato___Late_blight/*')),
    'healthy':list(data_dir.glob('Potato___healthy/*'))
}

# %%
potato_disease_test_dict={
    'early_blight':list(test_dir.glob('potato_early/*')),
    'late_blight':list(test_dir.glob('potato_late/*')),
    'healthy':list(test_dir.glob('potato_healthy/*'))
}

# %%
potato_disease_test_dict
# Out:
# {'early_blight': [PosixPath('../Dataset/potato_test/potato_early/potato_early_1120_gblr_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_736.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_683.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_235.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1050_gblr_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1120_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1020_ccrp_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_329.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1121_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1151_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1118_gblr_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1148_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1020_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_903.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1053_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1019_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1128_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1065_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1010_gblr_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_253.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1081_gblr_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1036_gblr_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1093_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1152_rrot_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_924.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_698.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1158_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_293.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1134_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1061_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_951.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1085_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_373.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1140_ccrp_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1121_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1121_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1145_rrot_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_858.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_586.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_904.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_850.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1107_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1157_gblr_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_947.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1051_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1158_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_816.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1032_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1047_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_735.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1065_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1048_rrot_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1042_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_165.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_514.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1077_ccrp_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_945.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1112_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1039_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_448.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1146_ccrp_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1039_gblr_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_375.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1053_rrot_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1061_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1033_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1131_gblr_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1127_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1047_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_691.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1129_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_884.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1098_ccrp_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_672.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_938.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1151_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_241.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_753.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_577.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1140_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1094_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1143_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_541.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_429.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1116_ccrp_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1057_gblr_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_726.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1075_rrot_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1118_ccrp_3.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_446.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1124_ccrp_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_833.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1087_gblr_4.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1137_gblr_1.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_608.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_1126_ccrp_2.JPG'),
#   PosixPath('../Dataset/potato_test/potato_early/potato_early_
X_test,y_test=[],[]
for disease_name, images in potato_disease_dict.items():
    for image in images:
        img=cv2.imread(str(image))
        resized_img=cv2.resize(img,(224,224))
        X.append(resized_img)
        y.append(potato_lablels_dict[disease_name])

for disease_name, images in potato_disease_test_dict.items():
    for image in images:
        img=cv2.imread(str(image))
        resized_img=cv2.resize(img,(224,224))
        X_test.append(resized_img)
        y_test.append(potato_lablels_dict[disease_name])

# %%
img_height,img_width=X[0].shape[:2]

# %%
X[0].shape
# Out:
# (224, 224, 3)

# %%
X=np.array(X)
y=np.array(y)

X_test=np.array(X_test)
y_test=np.array(y_test)


from sklearn.utils import shuffle
X_test, y_test = shuffle(X_test, y_test, random_state=42)

# %%
y_test[:10]
# Out:
# array([1, 2, 1, 0, 2, 1, 2, 2, 0, 1])

# %%
from sklearn.model_selection import train_test_split
X_train,X_valid,y_train,y_valid=train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=42,shuffle=True)

# %%
print(len(X_train))
print(len(X_valid))
print(len(y_train))
print(len(y_valid))
# Out:
# 1721
# 431
# 1721
# 431

# %%
X_train_scaled=X_train/255
X_valid_scaled=X_valid/255
X_test_scaled=X_test/255

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
num_classes=5
augmented_model=Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=X[0].shape),
    layers.experimental.preprocessing.RandomZoom(0.1),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomContrast(0.5),
    layers.experimental.preprocessing.RandomFlip(),    
])
# Out:
# 2023-10-25 18:40:39.622596: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
import matplotlib.pyplot as plt
plt.imshow(X[0])

# %%
#plt.imshow(augmented_model(X)[0].numpy().astype("uint8"))

# %%
num_classes=5
model=Sequential([
    augmented_model,
    layers.Conv2D(32,3, padding='same', input_shape=X[0].shape, activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
             metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
es=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=5,restore_best_weights=True,start_from_epoch=5)

# %%
history=model.fit(X_train_scaled,y_train,
          validation_data=(X_valid_scaled,y_valid),
          batch_size=64,
          epochs=50,
          callbacks=[es]
         )
# Out:
# Epoch 1/50
# 27/27 [==============================] - 90s 3s/step - loss: 1.0587 - accuracy: 0.4631 - val_loss: 0.9583 - val_accuracy: 0.4548
# Epoch 2/50
# 27/27 [==============================] - 89s 3s/step - loss: 0.8588 - accuracy: 0.5689 - val_loss: 0.7330 - val_accuracy: 0.7958
# Epoch 3/50
# 27/27 [==============================] - 82s 3s/step - loss: 0.6688 - accuracy: 0.7443 - val_loss: 1.0666 - val_accuracy: 0.3944
# Epoch 4/50
# 27/27 [==============================] - 82s 3s/step - loss: 0.5252 - accuracy: 0.8030 - val_loss: 0.4283 - val_accuracy: 0.8515
# Epoch 5/50
# 27/27 [==============================] - 85s 3s/step - loss: 0.3833 - accuracy: 0.8466 - val_loss: 0.3360 - val_accuracy: 0.8585
# Epoch 6/50
# 27/27 [==============================] - 81s 3s/step - loss: 0.3764 - accuracy: 0.8489 - val_loss: 0.2786 - val_accuracy: 0.9165
# Epoch 7/50
# 27/27 [==============================] - 83s 3s/step - loss: 0.3270 - accuracy: 0.8623 - val_loss: 0.3704 - val_accuracy: 0.8492
# Epoch 8/50
# 27/27 [==============================] - 79s 3s/step - loss: 0.3133 - accuracy: 0.8646 - val_loss: 0.2733 - val_accuracy: 0.9188
# Epoch 9/50
# 27/27 [==============================] - 81s 3s/step - loss: 0.2837 - accuracy: 0.8908 - val_loss: 0.2399 - val_accuracy: 0.9049
# Epoch 10/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.2467 - accuracy: 0.9012 - val_loss: 0.2040 - val_accuracy: 0.9258
# Epoch 11/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.2268 - accuracy: 0.9192 - val_loss: 0.1874 - val_accuracy: 0.9443
# Epoch 12/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.1661 - accuracy: 0.9349 - val_loss: 0.1563 - val_accuracy: 0.9374
# Epoch 13/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.1752 - accuracy: 0.9309 - val_loss: 0.2172 - val_accuracy: 0.9002
# Epoch 14/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.1771 - accuracy: 0.9320 - val_loss: 0.1241 - val_accuracy: 0.9559
# Epoch 15/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.1633 - accuracy: 0.9384 - val_loss: 0.1673 - val_accuracy: 0.9420
# Epoch 16/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.2046 - accuracy: 0.9198 - val_loss: 0.2172 - val_accuracy: 0.9165
# Epoch 17/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.1879 - accuracy: 0.9262 - val_loss: 0.1898 - val_accuracy: 0.9211
# Epoch 18/50
# 27/27 [==============================] - 71s 3s/step - loss: 0.2314 - accuracy: 0.9064 - val_loss: 0.2750 - val_accuracy: 0.8886
# Epoch 19/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9250Restoring model weights from the end of the best epoch: 14.
# 27/27 [==============================] - 72s 3s/step - loss: 0.1768 - accuracy: 0.9250 - val_loss: 0.1485 - val_accuracy: 0.9420
# Epoch 19: early stopping

# %%
model.save('../models/saved_models/1/PLIDD_model1.pb')
# Out:
# 2023-10-25 18:34:16.239499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'random_flip_input' with dtype float and shape [?,224,224,3]
# 	 [[{{node random_flip_input}}]]
# 2023-10-25 18:34:16.497955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.526135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'random_flip_input' with dtype float and shape [?,224,224,3]
# 	 [[{{node random_flip_input}}]]
# 2023-10-25 18:34:16.551364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.566672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.582006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.606812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.637828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.748612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'sequential_input' with dtype float and shape [?,224,224,3]
# 	 [[{{node sequential_input}}]]
# 2023-10-25 18:34:16.905711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:16.968405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'sequential_input' with dtype float and shape [?,224,224,3]
# 	 [[{{node sequential_input}}]]
# 2023-10-25 18:34:17.063970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7,7,128]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:17.115745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:17.262523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:17.655674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:18.012299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7,7,128]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:18.066546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:18.109347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:18.175228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# 2023-10-25 18:34:18.286415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,224,224,3]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/saved_models/1/PLIDD_model1.pb/assets
# INFO:tensorflow:Assets written to: ../models/saved_models/1/PLIDD_model1.pb/assets

# %%
plt.plot(history.epoch,history.history["accuracy"])
plt.plot(history.epoch,history.history["val_accuracy"])
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.show()

# %%
model=keras.models.load_model('../models/saved_models/1/PLIDD_model1.pb')
# Out:
# 2023-10-25 18:46:15.749383: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
import gc
gc.collect()
# Out:
# 2665

# %%
model.evaluate(X_valid_scaled,y_valid)
# Out:
# 14/14 [==============================] - 5s 338ms/step - loss: 0.1241 - accuracy: 0.9559
# [0.12412010878324509, 0.9559164643287659]

# %%
gc.collect()
# Out:
# 597

# %%
#test_evaluation=model.evaluate(X_test_scaled,y_test)

# %%
#predictions=[np.argmax(model.predict(np.array([X_test_scaled[i]])))==y_test[i] for i in range(len(X_test_scaled))]

# %%
predictions=model.predict(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 predictions=model.predict(X_test_scaled)
#
# NameError: name 'model' is not defined

# %%
predictions2=[np.argmax(predictions[i]) for i in range(len(X_test_scaled))]
predictions3=[np.argmax(predictions[i])==y_test[i] for i in range(len(X_test_scaled))]

# %%
np.argmax(model.predict(np.array([X_test_scaled[4]])))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 2

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cf=confusion_matrix(predictions2,y_test)

# %%
cf
# Out:
# array([[2109,  152,   90],
#        [ 110, 2049,  258],
#        [   0,   18, 1702]])

# %%
import seaborn as sb
sb.heatmap(cf, annot=True,fmt='', cmap='Blues');

# %%
import seaborn as sb
sb.heatmap(cf/np.sum(cf), annot=True,fmt='.2%', cmap='Blues');

# %%
import tensorflow_hub as hub

# %%
pre_trained_model= tf.keras.Sequential(
    [
        hub.KerasLayer("https://tfhub.dev/rishit-dagli/plant-disease/1",input_shape=(224,224,3),trainable=False)
    ]
)

# %%
TL_model=keras.Sequential([
    pre_trained_model,
    keras.layers.Dense(3)
])
TL_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 38)                3267814
#
#  dense_2 (Dense)             (None, 3)                 117
#
# =================================================================
# Total params: 3267931 (12.47 MB)
# Trainable params: 117 (468.00 Byte)
# Non-trainable params: 3267814 (12.47 MB)
# _________________________________________________________________

# %%
TL_model.compile(optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
             metrics=['accuracy'])

# %%
history=TL_model.fit(X_train_scaled,y_train,
          validation_data=(X_valid_scaled,y_valid),
          batch_size=64,
          epochs=50,
          callbacks=[es]
         )
# Out:
# Epoch 1/50
# 2023-09-29 22:46:28.996903: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1036234752 exceeds 10% of free system memory.
# 27/27 [==============================] - 32s 1s/step - loss: 3.5995 - accuracy: 0.4898 - val_loss: 3.5633 - val_accuracy: 0.5592
# Epoch 2/50
# 27/27 [==============================] - 29s 1s/step - loss: 3.1580 - accuracy: 0.5828 - val_loss: 3.3059 - val_accuracy: 0.5963
# Epoch 3/50
# 27/27 [==============================] - 29s 1s/step - loss: 2.9296 - accuracy: 0.5671 - val_loss: 3.0312 - val_accuracy: 0.5777
# Epoch 4/50
# 27/27 [==============================] - 30s 1s/step - loss: 2.6222 - accuracy: 0.5782 - val_loss: 2.7274 - val_accuracy: 0.5893
# Epoch 5/50
# 27/27 [==============================] - 29s 1s/step - loss: 2.3052 - accuracy: 0.6014 - val_loss: 2.3462 - val_accuracy: 0.6079
# Epoch 6/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.9602 - accuracy: 0.6084 - val_loss: 1.9940 - val_accuracy: 0.6148
# Epoch 7/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.6062 - accuracy: 0.6246 - val_loss: 1.8174 - val_accuracy: 0.6172
# Epoch 8/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.5046 - accuracy: 0.6328 - val_loss: 1.7387 - val_accuracy: 0.6334
# Epoch 9/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.4699 - accuracy: 0.6345 - val_loss: 1.6027 - val_accuracy: 0.6404
# Epoch 10/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.4347 - accuracy: 0.6421 - val_loss: 1.5570 - val_accuracy: 0.6427
# Epoch 11/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.3349 - accuracy: 0.6549 - val_loss: 1.5022 - val_accuracy: 0.6381
# Epoch 12/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.2524 - accuracy: 0.6688 - val_loss: 1.3960 - val_accuracy: 0.6845
# Epoch 13/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.1867 - accuracy: 0.6967 - val_loss: 1.3228 - val_accuracy: 0.6775
# Epoch 14/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.1404 - accuracy: 0.7095 - val_loss: 1.2909 - val_accuracy: 0.7146
# Epoch 15/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.1064 - accuracy: 0.7240 - val_loss: 1.2233 - val_accuracy: 0.7262
# Epoch 16/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.0645 - accuracy: 0.7333 - val_loss: 1.1912 - val_accuracy: 0.7541
# Epoch 17/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.0261 - accuracy: 0.7414 - val_loss: 1.1125 - val_accuracy: 0.7587
# Epoch 18/50
# 27/27 [==============================] - 29s 1s/step - loss: 1.0066 - accuracy: 0.7438 - val_loss: 1.0657 - val_accuracy: 0.7587
# Epoch 19/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9898 - accuracy: 0.7484 - val_loss: 1.1082 - val_accuracy: 0.7889
# Epoch 20/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9815 - accuracy: 0.7658 - val_loss: 1.0858 - val_accuracy: 0.7889
# Epoch 21/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9650 - accuracy: 0.7711 - val_loss: 1.0831 - val_accuracy: 0.7912
# Epoch 22/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9559 - accuracy: 0.7734 - val_loss: 1.0828 - val_accuracy: 0.7958
# Epoch 23/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9468 - accuracy: 0.7745 - val_loss: 1.0599 - val_accuracy: 0.8005
# Epoch 24/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9427 - accuracy: 0.7775 - val_loss: 1.0563 - val_accuracy: 0.8005
# Epoch 25/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9405 - accuracy: 0.7775 - val_loss: 1.0533 - val_accuracy: 0.8051
# Epoch 26/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.9375 - accuracy: 0.7792 - val_loss: 1.0511 - val_accuracy: 0.8051
# Epoch 27/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8991 - accuracy: 0.7804 - val_loss: 1.0119 - val_accuracy: 0.7889
# Epoch 28/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8813 - accuracy: 0.7815 - val_loss: 0.9836 - val_accuracy: 0.7889
# Epoch 29/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8606 - accuracy: 0.7821 - val_loss: 0.9553 - val_accuracy: 0.7865
# Epoch 30/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8301 - accuracy: 0.7833 - val_loss: 0.9222 - val_accuracy: 0.7842
# Epoch 31/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8199 - accuracy: 0.7827 - val_loss: 0.9185 - val_accuracy: 0.7889
# Epoch 32/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8123 - accuracy: 0.7844 - val_loss: 0.9156 - val_accuracy: 0.7935
# Epoch 33/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.8098 - accuracy: 0.7838 - val_loss: 0.9129 - val_accuracy: 0.7912
# Epoch 34/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7786 - accuracy: 0.7862 - val_loss: 0.8616 - val_accuracy: 0.7865
# Epoch 35/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7618 - accuracy: 0.7844 - val_loss: 0.8535 - val_accuracy: 0.7889
# Epoch 36/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7442 - accuracy: 0.7862 - val_loss: 0.8261 - val_accuracy: 0.7958
# Epoch 37/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7314 - accuracy: 0.7897 - val_loss: 0.8201 - val_accuracy: 0.8005
# Epoch 38/50
# 27/27 [==============================] - 30s 1s/step - loss: 0.7276 - accuracy: 0.7920 - val_loss: 0.8153 - val_accuracy: 0.8028
# Epoch 39/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7250 - accuracy: 0.7966 - val_loss: 0.8124 - val_accuracy: 0.8028
# Epoch 40/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7235 - accuracy: 0.7978 - val_loss: 0.8074 - val_accuracy: 0.8051
# Epoch 41/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7210 - accuracy: 0.8001 - val_loss: 0.8054 - val_accuracy: 0.8051
# Epoch 42/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7176 - accuracy: 0.8019 - val_loss: 0.8039 - val_accuracy: 0.8051
# Epoch 43/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7153 - accuracy: 0.8024 - val_loss: 0.8017 - val_accuracy: 0.8097
# Epoch 44/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7141 - accuracy: 0.8030 - val_loss: 0.7996 - val_accuracy: 0.8074
# Epoch 45/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7126 - accuracy: 0.8024 - val_loss: 0.7978 - val_accuracy: 0.8074
# Epoch 46/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.7111 - accuracy: 0.8024 - val_loss: 0.7983 - val_accuracy: 0.8051
# Epoch 47/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.6992 - accuracy: 0.8141 - val_loss: 0.7347 - val_accuracy: 0.8399
# Epoch 48/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.6744 - accuracy: 0.8234 - val_loss: 0.7315 - val_accuracy: 0.8445
# Epoch 49/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.6704 - accuracy: 0.8257 - val_loss: 0.7289 - val_accuracy: 0.8492
# Epoch 50/50
# 27/27 [==============================] - 29s 1s/step - loss: 0.6639 - accuracy: 0.8251 - val_loss: 0.7314 - val_accuracy: 0.8469
