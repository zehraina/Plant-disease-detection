# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import gc
import PIL
import tensorflow as tf
from tensorflow import keras
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import pathlib
main_dir="../Dataset/PlantVillage"
train_dir=os.path.join(main_dir,'train')
test_dir=os.path.join(main_dir,'test')
valid_dir=os.path.join(main_dir,'validation')

data_dir='../Dataset/PlantVillage'
#test_dir='Dataset//'
data_dir=pathlib.Path(data_dir)
#test_dir=pathlib.Path(test_dir)
data_dir
# Out:
# PosixPath('/kaggle/input/plant-village-mini-dataset/Dataset/PlantVillage')

# %%
os.listdir(train_dir)
# Out:
# ['validation', 'test', 'train']

# %%
disease_dict={
    'potato_early_blight':list(train_dir.glob('0_Potato___early_blight/*')),
    'potato_late_blight':list(train_dir.glob('0_Potato___late_blight/*')),
    'potato_healthy':list(train_dir.glob('0_Potato___healthy/*')),
    
    'tomato_bacterial_spot':list(train_dir.glob('1_Tomato___bacterial spot/*')),
    'tomato_early_blight':list(train_dir.glob('1_Tomato___Early_blight/*')),
    'tomato_late_blight':list(train_dir.glob('1_Tomato___Late_blight/*')),
    'tomato_leaf_mold':list(train_dir.glob('1_Tomato___leaf/*')),
    'tomato_septoria_leaf_spot':list(train_dir.glob('1_Tomato___septoria leaf spot/*')),
    'tomato_spider_mites_two-spotted_spider_mite':list(train_dir.glob('1_Tomato___spider mites two-spotted spider mite/*')),
    'tomato_target_spot':list(train_dir.glob('1_Tomato___target spot/*')),
    'tomato_mosaic_virus':list(train_dir.glob('1_Tomato___tomato mosaic virus/*')),
    'tomato_yellow_leaf_curl_virus':list(train_dir.glob('1_Tomato___tomato yellow leaf curl virus/*')),
    'tomato_healthy':list(train_dir.glob('1_Tomato___healthy/*')),
    
    'corn_cercospora_leaf_spot_gray_leaf_spot':list(train_dir.glob('2_Corn___cercospora leaf spot gray leaf spot/*')),
    'corn_common rust':list(train_dir.glob('2_Corn___common rust/*')),
    'corn_northern_leaf_blight':list(train_dir.glob('2_Corn___northern leaf blight/*')),
    'corn_healthy':list(train_dir.glob('2_Corn___healthy/*')),
}

# %%
disease_dict
# Out:
# {'potato_early_blight': [],
#  'potato_late_blight': [],
#  'potato_healthy': [],
#  'tomato_bacterial_spot': [],
#  'tomato_early_blight': [],
#  'tomato_late_blight': [],
#  'tomato_leaf_mold': [],
#  'tomato_septoria_leaf_spot': [],
#  'tomato_spider_mites_two-spotted_spider_mite': [],
#  'tomato_target_spot': [],
#  'tomato_mosaic_virus': [],
#  'tomato_yellow_leaf_curl_virus': [],
#  'tomato_healthy': [],
#  'corn_cercospora_leaf_spot_gray_leaf_spot': [],
#  'corn_common rust': [],
#  'corn_northern_leaf_blight': [],
#  'corn_healthy': []}

# %%
labels_dict={}
i=0
for lablels in disease_dict.keys():
    labels_dict[lablels]=i
    i+=1
labels_dict
# Out:
# {'potato_early_blight': 0,
#  'potato_late_blight': 1,
#  'potato_healthy': 2,
#  'tomato_bacterial_spot': 3,
#  'tomato_early_blight': 4,
#  'tomato_late_blight': 5,
#  'tomato_leaf_mold': 6,
#  'tomato_septoria_leaf_spot': 7,
#  'tomato_spider_mites_two-spotted_spider_mite': 8,
#  'tomato_target_spot': 9,
#  'tomato_mosaic_virus': 10,
#  'tomato_yellow_leaf_curl_virus': 11,
#  'tomato_healthy': 12,
#  'corn_cercospora_leaf_spot_gray_leaf_spot': 13,
#  'corn_common rust': 14,
#  'corn_northern_leaf_blight': 15,
#  'corn_healthy': 16}

# %%
gc.collect()
# Out:
# 0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=0.2,
    brightness_range=(0.3,0.9),
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
)

test_datagen=ImageDataGenerator(rescale=1./255)
validation_datagen=ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_directory(
    train_dir,
    target_size=(180,180),
    batch_size=64,
    class_mode='categorical'
)
test_generator=test_datagen.flow_from_directory(
    test_dir,
    target_size=(180,180),
    batch_size=64,
    class_mode='categorical'
)
valid_generator=train_datagen.flow_from_directory(
    valid_dir,
    target_size=(180,180),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 15325 images belonging to 17 classes.
# Found 2411 images belonging to 17 classes.
# Found 4344 images belonging to 17 classes.

# %%
gc.collect()
# Out:
# 0

# %%
#plt.imshow(augmented_model(X)[0].numpy().astype("uint8"))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
num_classes=17
model=Sequential([
    layers.Conv2D(32,3, padding='same', input_shape=(180,180,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dense(num_classes,activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 128)       0
#
#  flatten (Flatten)           (None, 15488)             0
#
#  dense (Dense)               (None, 128)               1982592
#
#  dense_1 (Dense)             (None, 17)                2193
#
# ...
# Total params: 2,225,617
# Trainable params: 2,225,617
# ...

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
es=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=5,restore_best_weights=True,start_from_epoch=5)

# %%
history=model.fit(train_generator,
          validation_data=valid_generator,
          epochs=50,
          batch_size=32,
          callbacks=[es]
         )
# Out:
# Epoch 1/50
# 2023-10-27 18:18:11.448157: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_1/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 240/240 [==============================] - 174s 714ms/step - loss: 1.4555 - accuracy: 0.5396 - val_loss: 0.8821 - val_accuracy: 0.7095
# Epoch 2/50
# 240/240 [==============================] - 168s 700ms/step - loss: 0.7908 - accuracy: 0.7372 - val_loss: 0.7571 - val_accuracy: 0.7535
# Epoch 3/50
# 240/240 [==============================] - 167s 696ms/step - loss: 0.6172 - accuracy: 0.7946 - val_loss: 0.5474 - val_accuracy: 0.8064
# Epoch 4/50
# 240/240 [==============================] - 169s 704ms/step - loss: 0.5163 - accuracy: 0.8284 - val_loss: 0.4476 - val_accuracy: 0.8483
# Epoch 5/50
# ...

# %%
model.save('model2.pb')

# %%
plt.plot(history.epoch,history.history["accuracy"])
plt.plot(history.epoch,history.history["val_accuracy"])
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.show()

# %%
import gc
gc.collect()
# Out:
# 0

# %%
model=keras.models.load_model('model2.pb')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model=keras.models.load_model('model2.pb')
#
# File /opt/conda/lib/python3.10/site-packages/keras/saving/saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
# ...

# %%
model.evaluate(test_generator)

# %%
test_loss,test_acc=model.evaluate(test_generator)
print('test acc : {} test loss : {}'.format(test_acc,test_loss))
# Out:
# 2023-10-04 11:20:14.929873: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2522534400 exceeds 10% of free system memory.
# 203/203 [==============================] - 41s 201ms/step - loss: 0.2794 - accuracy: 0.9032

# %%
#predictions=[np.argmax(model.predict(np.array([X_test_scaled[i]])))==y_test[i] for i in range(len(X_test_scaled))]
